# %% [markdown]
# # Canny Edge Detection

# %% [markdown]
# ## Import Library

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os

# %% [markdown]
# ## Load Image

# %%
image_path = os.path.join(os.getcwd(), 'data', 'gambar.JPEG')
img_data = cv2.imread(image_path)

# preview using matplotlib (jangan lupa konversi BGR ke RGB)
plt.imshow(cv2.cvtColor(img_data, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# # 1. Pre-processing

# %%
print(f"Original Image size): {img_data.shape}")

ratio = img_data.shape[0] / 500.0
resized_img = cv2.resize(img_data, (int(img_data.shape[1] / ratio), 500))
resize_img_gray = cv2.cvtColor(resized_img, cv2.COLOR_BGR2GRAY)
res_gray_blur = cv2.GaussianBlur(resize_img_gray, (5, 5), 0)
# Out:
# Original Image size): (1600, 1200, 3)

# %% [markdown]
# ## Preview Pre-processing

# %%
# Create subplot untuk menampilkan perubahan image
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Original resized image
axes[0, 0].imshow(cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB))
axes[0, 0].set_title('Resized Image')
axes[0, 0].axis('off')

# Grayscale image
axes[0, 1].imshow(resize_img_gray, cmap='gray')
axes[0, 1].set_title('Grayscale Image')
axes[0, 1].axis('off')

# Blurred grayscale image
axes[1, 0].imshow(res_gray_blur, cmap='gray')
axes[1, 0].set_title('Blurred Grayscale Image')
axes[1, 0].axis('off')

# Hide the last subplot
axes[1, 1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Canny Detection

# %%
# Perbaikan: Menurunkan nilai threshold agar garis tepi bisa terdeteksi
edge = cv2.Canny(res_gray_blur, 50, 150)

# Dilatasi
kernel = np.ones((3, 3), np.uint8)
edged = cv2.dilate(edge, kernel, iterations=1)

# Menampilkan hasil
plt.imshow(edged, cmap='gray')
plt.title('Canny Edges after Dilation')
plt.axis('off')
plt.show()

# %% [markdown]
# # 3. Find Contours

# %%
contours, _ = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
# print(f"Isi dari: {contours[:5]}")  # Menampilkan 10 kontur pertama untuk referensi
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %% [markdown]
# ### Cari Titik Sudut

# %%
document_contour = None

for i, contour in enumerate(contours):
    peri = cv2.arcLength(contour, True)
    area = cv2.contourArea(contour)
    
    # Buat titik approximation
    approx = cv2.approxPolyDP(contour, 0.02 * peri, True)
    print(f"Contour #{i}: Area = {area}, Perimeter = {peri}, Vertices = {len(approx)}")
    
    if len(approx) == 4 and area > 10000:
        document_contour = approx
        print(f"Document contour found with area: {area}")
        break
# Out:
# Contour #0: Area = 4005.5, Perimeter = 3209.7716398239136, Vertices = 13
# Contour #1: Area = 2819.5, Perimeter = 385.92387998104095, Vertices = 5
# Contour #2: Area = 2079.0, Perimeter = 390.53405475616455, Vertices = 11
# Contour #3: Area = 1508.0, Perimeter = 323.7401144504547, Vertices = 5
# Contour #4: Area = 827.0, Perimeter = 161.96551275253296, Vertices = 7
# Contour #5: Area = 536.0, Perimeter = 203.5979790687561, Vertices = 4
# Contour #6: Area = 471.0, Perimeter = 126.14213538169861, Vertices = 8
# Contour #7: Area = 386.5, Perimeter = 153.69848430156708, Vertices = 8
# Contour #8: Area = 351.5, Perimeter = 138.87005722522736, Vertices = 5
# Contour #9: Area = 320.5, Perimeter = 127.55634891986847, Vertices = 5

# %% [markdown]
# ### Preview Contour dari Dokumen

# %%
contour_image = resized_img.copy()
cv2.drawContours(contour_image, [document_contour], -1, (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB))
plt.title('Document Contour')
plt.axis('off')
plt.show()

# %% [markdown]
# # 4. Transformasi Perspektif

# %%
pts = document_contour.reshape(4, 2) * ratio
rect = np.zeros((4, 2), dtype="float32")
s = pts.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 pts = document_contour.reshape(4, 2) * ratio
#       2 rect = np.zeros((4, 2), dtype="float32")
#       3 s = pts.sum(axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'reshape'

# %%
rect[0] = pts[np.argmin(s)] # kiri atas
rect[2] = pts[np.argmax(s)] # kanan bawah
diff = np.diff(pts, axis=1)
rect[1] = pts[np.argmin(diff)] # kanan atas
rect[3] = pts[np.argmax(diff)] # kiri bawah

print(f"Original Image size): {img_data.shape}")
print(f"Document corners (after scaling): {rect}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 rect[0] = pts[np.argmin(s)] # kiri atas
#       2 rect[2] = pts[np.argmax(s)] # kanan bawah
#       3 diff = np.diff(pts, axis=1)
#
# NameError: name 'pts' is not defined

# %%
tl, tr, br, bl = rect
widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
maxWidth = max(int(widthA), int(widthB))

heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
maxHeight = max(int(heightA), int(heightB))

print(f"maxWidth: {maxWidth}, maxHeight: {maxHeight}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tl, tr, br, bl = rect
#       2 widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
#       3 widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
#
# NameError: name 'rect' is not defined

# %%
dst = np.array([
    [0, 0],
    [maxWidth - 1, 0],
    [maxWidth - 1, maxHeight - 1],
    [0, maxHeight - 1]
], dtype="float32")

print(f"dst: {dst}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 dst = np.array([
#       2     [0, 0],
# ----> 3     [maxWidth - 1, 0],
#       4     [maxWidth - 1, maxHeight - 1],
#       5     [0, maxHeight - 1]
#       6 ], dtype="float32")
#       8 print(f"dst: {dst}")
#
# NameError: name 'maxWidth' is not defined

# %%
# Transformasi Perspektif

M = cv2.getPerspectiveTransform(rect, dst)
warped = cv2.warpPerspective(img_data, M, (maxWidth, maxHeight))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Transformasi Perspektif
# ----> 3 M = cv2.getPerspectiveTransform(rect, dst)
#       4 warped = cv2.warpPerspective(img_data, M, (maxWidth, maxHeight))
#
# NameError: name 'rect' is not defined

# %%
# Preview hasil transformasi perspektif
plt.imshow(cv2.cvtColor(warped, cv2.COLOR_BGR2RGB))
plt.title('Warped Image (Top-Down View)')
plt.axis('off')
output_path = os.path.join(os.getcwd(), 'scanned_document.jpg')
cv2.imwrite(output_path, warped)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Preview hasil transformasi perspektif
# ----> 2 plt.imshow(cv2.cvtColor(warped, cv2.COLOR_BGR2RGB))
#       3 plt.title('Warped Image (Top-Down View)')
#       4 plt.axis('off')
#
# NameError: name 'warped' is not defined

# %%
warped_gray = cv2.cvtColor(warped, cv2.COLOR_BGR2GRAY)

threshold = cv2.adaptiveThreshold(warped_gray, 255,
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                        cv2.THRESH_BINARY,
                                        11,
                                        2)

clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
enhanced_image = clahe.apply(warped_gray)

plt.imshow(enhanced_image, cmap='gray')
plt.title('Enhanced Contrast Image using CLAHE')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 warped_gray = cv2.cvtColor(warped, cv2.COLOR_BGR2GRAY)
#       3 threshold = cv2.adaptiveThreshold(warped_gray, 255,
#       4                                         cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
#       5                                         cv2.THRESH_BINARY,
#       6                                         11,
#       7                                         2)
#       9 clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
#
# NameError: name 'warped' is not defined

# %%
enhanced_image_contrast = cv2.convertScaleAbs(enhanced_image, alpha=1.3, beta=63)

plt.imshow(enhanced_image_contrast, cmap='gray')
plt.title('Enhanced Contrast Image after Scaling')
plt.axis('off')
plt.show()

# save image final
final_output_path = os.path.join(os.getcwd(), 'final_enhanced_document_contrast.jpg')
cv2.imwrite(final_output_path, enhanced_image_contrast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 enhanced_image_contrast = cv2.convertScaleAbs(enhanced_image, alpha=1.3, beta=63)
#       3 plt.imshow(enhanced_image_contrast, cmap='gray')
#       4 plt.title('Enhanced Contrast Image after Scaling')
#
# NameError: name 'enhanced_image' is not defined

# %%
lab_color = cv2.cvtColor(warped, cv2.COLOR_BGR2LAB)
l_channel, a_channel, b_channel = cv2.split(lab_color)
l_channel = clahe.apply(l_channel)
enhanced_lab_img = cv2.merge((l_channel, a_channel, b_channel))
white_balanced_img = cv2.cvtColor(enhanced_lab_img, cv2.COLOR_LAB2BGR)

plt.imshow(white_balanced_img)
plt.title('White Balanced Image using CLAHE on L Channel')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 lab_color = cv2.cvtColor(warped, cv2.COLOR_BGR2LAB)
#       2 l_channel, a_channel, b_channel = cv2.split(lab_color)
#       3 l_channel = clahe.apply(l_channel)
#
# NameError: name 'warped' is not defined

# %%
# Save final image
final_output_path = os.path.join(os.getcwd(), 'final_enhanced_document.jpg')
cv2.imwrite(final_output_path, white_balanced_img)
# Out:
# True
